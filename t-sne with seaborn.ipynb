# %%
import numpy as np
from sklearn.datasets import load_digits
from scipy.spatial.distance import pdist
from sklearn.manifold.t_sne import _joint_probabilities
from scipy import linalg
from sklearn.metrics import pairwise_distances
from scipy.spatial.distance import squareform
from sklearn.manifold import TSNE
from matplotlib import pyplot as plt
import seaborn as sns
sns.set(rc={'figure.figsize':(11.7,8.27)})
palette = sns.color_palette("bright", 10)
X, y = load_digits(return_X_y=True)
MACHINE_EPSILON = np.finfo(np.double).eps
n_components = 2
perplexity = 30
def fit(X):
    n_samples = X.shape[0]
    
    # Compute euclidean distance
    distances = pairwise_distances(X, metric='euclidean', squared=True)
    
    # Compute joint probabilities p_ij from distances.
    P = _joint_probabilities(distances=distances, desired_perplexity=perplexity, verbose=False)
    
    # The embedding is initialized with iid samples from Gaussians with standard deviation 1e-4.
    X_embedded = 1e-4 * np.random.mtrand._rand.randn(n_samples, n_components).astype(np.float32)
    
    # degrees_of_freedom = n_components - 1 comes from
    # "Learning a Parametric Embedding by Preserving Local Structure"
    # Laurens van der Maaten, 2009.
    degrees_of_freedom = max(n_components - 1, 1)
    
    return _tsne(P, degrees_of_freedom, n_samples, X_embedded=X_embedded)

def _tsne(P, degrees_of_freedom, n_samples, X_embedded):
    params = X_embedded.ravel()
    
    obj_func = _kl_divergence
    
    params = _gradient_descent(obj_func, params, [P, degrees_of_freedom, n_samples, n_components])
        
    X_embedded = params.reshape(n_samples, n_components)
    
    return X_embedded

def _kl_divergence(params, P, degrees_of_freedom, n_samples, n_components):
    X_embedded = params.reshape(n_samples, n_components)
    
    dist = pdist(X_embedded, "sqeuclidean")
    dist /= degrees_of_freedom
    dist += 1.
    dist **= (degrees_of_freedom + 1.0) / -2.0
    Q = np.maximum(dist / (2.0 * np.sum(dist)), MACHINE_EPSILON)
    
    # Kullback-Leibler divergence of P and Q
    kl_divergence = 2.0 * np.dot(P, np.log(np.maximum(P, MACHINE_EPSILON) / Q))
    
    # Gradient: dC/dY
    grad = np.ndarray((n_samples, n_components), dtype=params.dtype)
    PQd = squareform((P - Q) * dist)
    for i in range(n_samples):
        grad[i] = np.dot(np.ravel(PQd[i], order='K'),
                         X_embedded[i] - X_embedded)
    grad = grad.ravel()
    c = 2.0 * (degrees_of_freedom + 1.0) / degrees_of_freedom
    grad *= c
    
    return kl_divergence, grad

def _gradient_descent(obj_func, p0, args, it=0, n_iter=1000,
                      n_iter_check=1, n_iter_without_progress=300,
                      momentum=0.8, learning_rate=200.0, min_gain=0.01,
                      min_grad_norm=1e-7):
    
    p = p0.copy().ravel()
    update = np.zeros_like(p)
    gains = np.ones_like(p)
    error = np.finfo(np.float).max
    best_error = np.finfo(np.float).max
    best_iter = i = it
    
    for i in range(it, n_iter):
        error, grad = obj_func(p, *args)
        grad_norm = linalg.norm(grad)
        inc = update * grad < 0.0
        dec = np.invert(inc)
        gains[inc] += 0.2
        gains[dec] *= 0.8
        np.clip(gains, min_gain, np.inf, out=gains)
        grad *= gains
        update = momentum * update - learning_rate * grad
        p += update
        print("[t-SNE] Iteration %d: error = %.7f,"
                      " gradient norm = %.7f"
                      % (i + 1, error, grad_norm))
        
        if error < best_error:
            best_error = error
            best_iter = i
        elif i - best_iter > n_iter_without_progress:
            break
        
        if grad_norm <= min_grad_norm:
            break
    return p

def _gradient_descent(obj_func, p0, args, it=0, n_iter=1000,
                      n_iter_check=1, n_iter_without_progress=300,
                      momentum=0.8, learning_rate=200.0, min_gain=0.01,
                      min_grad_norm=1e-7):
    
    p = p0.copy().ravel()
    update = np.zeros_like(p)
    gains = np.ones_like(p)
    error = np.finfo(np.float).max
    best_error = np.finfo(np.float).max
    best_iter = i = it
    
    for i in range(it, n_iter):
        error, grad = obj_func(p, *args)
        grad_norm = linalg.norm(grad)
        inc = update * grad < 0.0
        dec = np.invert(inc)
        gains[inc] += 0.2
        gains[dec] *= 0.8
        np.clip(gains, min_gain, np.inf, out=gains)
        grad *= gains
        update = momentum * update - learning_rate * grad
        p += update
        print("[t-SNE] Iteration %d: error = %.7f,"
                      " gradient norm = %.7f"
                      % (i + 1, error, grad_norm))
        
        if error < best_error:
            best_error = error
            best_iter = i
        elif i - best_iter > n_iter_without_progress:
            break
        
        if grad_norm <= min_grad_norm:
            break
    return p

X_embedded = fit(X)
sns.scatterplot(X_embedded[:,0], X_embedded[:,1], hue=y, legend='full', palette=palette)
tsne = TSNE()
X_embedded = tsne.fit_transform(X)
sns.scatterplot(X_embedded[:,0], X_embedded[:,1], hue=y, legend='full', palette=palette)
# Out:
# [t-SNE] Iteration 1: error = 4.0229677, gradient norm = 0.0000051
# [t-SNE] Iteration 2: error = 4.0229676, gradient norm = 0.0000050
# [t-SNE] Iteration 3: error = 4.0229676, gradient norm = 0.0000060
# [t-SNE] Iteration 4: error = 4.0229676, gradient norm = 0.0000092
# [t-SNE] Iteration 5: error = 4.0229676, gradient norm = 0.0000157
# [t-SNE] Iteration 6: error = 4.0229674, gradient norm = 0.0000286
# [t-SNE] Iteration 7: error = 4.0229667, gradient norm = 0.0000559
# [t-SNE] Iteration 8: error = 4.0229638, gradient norm = 0.0001158
# [t-SNE] Iteration 9: error = 4.0229498, gradient norm = 0.0002532
# [t-SNE] Iteration 10: error = 4.0228765, gradient norm = 0.0005822
# [t-SNE] Iteration 11: error = 4.0224521, gradient norm = 0.0014008
# [t-SNE] Iteration 12: error = 4.0197902, gradient norm = 0.0034867
# [t-SNE] Iteration 13: error = 4.0024564, gradient norm = 0.0084989
# [t-SNE] Iteration 14: error = 3.9067665, gradient norm = 0.0162220
# [t-SNE] Iteration 15: error = 3.6219823, gradient norm = 0.0186199
# [t-SNE] Iteration 16: error = 3.2323393, gradient norm = 0.0152852
# [t-SNE] Iteration 17: error = 2.8851925, gradient norm = 0.0118663
# [t-SNE] Iteration 18: error = 2.6094316, gradient norm = 0.0095682
# [t-SNE] Iteration 19: error = 2.3925031, gradient norm = 0.0079498
# [t-SNE] Iteration 20: error = 2.2222425, gradient norm = 0.0068427
# [t-SNE] Iteration 21: error = 2.0876175, gradient norm = 0.0062424
# [t-SNE] Iteration 22: error = 1.9773210, gradient norm = 0.0058263
# [t-SNE] Iteration 23: error = 1.8845115, gradient norm = 0.0054283
# [t-SNE] Iteration 24: error = 1.8072135, gradient norm = 0.0050670
# [t-SNE] Iteration 25: error = 1.7431912, gradient norm = 0.0047001
# [t-SNE] Iteration 26: error = 1.6891834, gradient norm = 0.0044739
# [t-SNE] Iteration 27: error = 1.6419611, gradient norm = 0.0044670
# [t-SNE] Iteration 28: error = 1.5994009, gradient norm = 0.0041944
# [t-SNE] Iteration 29: error = 1.5618231, gradient norm = 0.0038658
# [t-SNE] Iteration 30: error = 1.5293584, gradient norm = 0.0037468
# [t-SNE] Iteration 31: error = 1.5006500, gradient norm = 0.0034918
# [t-SNE] Iteration 32: error = 1.4750773, gradient norm = 0.0033631
# [t-SNE] Iteration 33: error = 1.4518254, gradient norm = 0.0031622
# [t-SNE] Iteration 34: error = 1.4306350, gradient norm = 0.0030656
# [t-SNE] Iteration 35: error = 1.4110545, gradient norm = 0.0029681
# [t-SNE] Iteration 36: error = 1.3926602, gradient norm = 0.0028949
# [t-SNE] Iteration 37: error = 1.3752754, gradient norm = 0.0026946
# [t-SNE] Iteration 38: error = 1.3591546, gradient norm = 0.0025433
# [t-SNE] Iteration 39: error = 1.3444536, gradient norm = 0.0024096
# [t-SNE] Iteration 40: error = 1.3311913, gradient norm = 0.0023907
# [t-SNE] Iteration 41: error = 1.3186117, gradient norm = 0.0022933
# [t-SNE] Iteration 42: error = 1.3065385, gradient norm = 0.0022013
# [t-SNE] Iteration 43: error = 1.2949816, gradient norm = 0.0021008
# [t-SNE] Iteration 44: error = 1.2839790, gradient norm = 0.0020189
# [t-SNE] Iteration 45: error = 1.2733776, gradient norm = 0.0020010
# [t-SNE] Iteration 46: error = 1.2629914, gradient norm = 0.0019092
# [t-SNE] Iteration 47: error = 1.2530990, gradient norm = 0.0018503
# [t-SNE] Iteration 48: error = 1.2437896, gradient norm = 0.0018418
# [t-SNE] Iteration 49: error = 1.2348063, gradient norm = 0.0017892
# [t-SNE] Iteration 50: error = 1.2261020, gradient norm = 0.0017238
# [t-SNE] Iteration 51: error = 1.2175892, gradient norm = 0.0016446
# [t-SNE] Iteration 52: error = 1.2092790, gradient norm = 0.0015661
# [t-SNE] Iteration 53: error = 1.2012526, gradient norm = 0.0015083
# [t-SNE] Iteration 54: error = 1.1935071, gradient norm = 0.0014901
# [t-SNE] Iteration 55: error = 1.1859794, gradient norm = 0.0014249
# [t-SNE] Iteration 56: error = 1.1787178, gradient norm = 0.0013825
# [t-SNE] Iteration 57: error = 1.1717084, gradient norm = 0.0013748
# [t-SNE] Iteration 58: error = 1.1648691, gradient norm = 0.0013572
# [t-SNE] Iteration 59: error = 1.1582007, gradient norm = 0.0013073
# [t-SNE] Iteration 60: error = 1.1517774, gradient norm = 0.0012764
# [t-SNE] Iteration 61: error = 1.1455992, gradient norm = 0.0012563
# [t-SNE] Iteration 62: error = 1.1396033, gradient norm = 0.0012755
# [t-SNE] Iteration 63: error = 1.1337201, gradient norm = 0.0012810
# [t-SNE] Iteration 64: error = 1.1279141, gradient norm = 0.0012036
# [t-SNE] Iteration 65: error = 1.1222225, gradient norm = 0.0011393
# [t-SNE] Iteration 66: error = 1.1166732, gradient norm = 0.0011060
# [t-SNE] Iteration 67: error = 1.1113215, gradient norm = 0.0010553
# [t-SNE] Iteration 68: error = 1.1061901, gradient norm = 0.0010139
# [t-SNE] Iteration 69: error = 1.1012226, gradient norm = 0.0009852
# [t-SNE] Iteration 70: error = 1.0964000, gradient norm = 0.0010004
# [t-SNE] Iteration 71: error = 1.0916778, gradient norm = 0.0009444
# [t-SNE] Iteration 72: error = 1.0870907, gradient norm = 0.0009123
# [t-SNE] Iteration 73: error = 1.0826240, gradient norm = 0.0009173
# [t-SNE] Iteration 74: error = 1.0782463, gradient norm = 0.0009250
# [t-SNE] Iteration 75: error = 1.0739658, gradient norm = 0.0009701
# [t-SNE] Iteration 76: error = 1.0697630, gradient norm = 0.0009504
# [t-SNE] Iteration 77: error = 1.0656177, gradient norm = 0.0008087
# [t-SNE] Iteration 78: error = 1.0615910, gradient norm = 0.0008735
# [t-SNE] Iteration 79: error = 1.0576103, gradient norm = 0.0008110
# [t-SNE] Iteration 80: error = 1.0537088, gradient norm = 0.0007683
# [t-SNE] Iteration 81: error = 1.0498935, gradient norm = 0.0007758
# [t-SNE] Iteration 82: error = 1.0461450, gradient norm = 0.0007382
# [t-SNE] Iteration 83: error = 1.0424691, gradient norm = 0.0007596
# [t-SNE] Iteration 84: error = 1.0388377, gradient norm = 0.0007066
# [t-SNE] Iteration 85: error = 1.0352666, gradient norm = 0.0007087
# [t-SNE] Iteration 86: error = 1.0317535, gradient norm = 0.0007020
# [t-SNE] Iteration 87: error = 1.0282943, gradient norm = 0.0006728
# [t-SNE] Iteration 88: error = 1.0248951, gradient norm = 0.0006613
# [t-SNE] Iteration 89: error = 1.0215587, gradient norm = 0.0006574
# [t-SNE] Iteration 90: error = 1.0182833, gradient norm = 0.0006627
# [t-SNE] Iteration 91: error = 1.0150676, gradient norm = 0.0006445
# [t-SNE] Iteration 92: error = 1.0119077, gradient norm = 0.0006333
# [t-SNE] Iteration 93: error = 1.0087901, gradient norm = 0.0006146
# [t-SNE] Iteration 94: error = 1.0057220, gradient norm = 0.0006214
# [t-SNE] Iteration 95: error = 1.0027165, gradient norm = 0.0006056
# [t-SNE] Iteration 96: error = 0.9997827, gradient norm = 0.0005931
# [t-SNE] Iteration 97: error = 0.9969077, gradient norm = 0.0005963
# [t-SNE] Iteration 98: error = 0.9940761, gradient norm = 0.0005734
# [t-SNE] Iteration 99: error = 0.9912886, gradient norm = 0.0005505
# [t-SNE] Iteration 100: error = 0.9885589, gradient norm = 0.0005406
# [t-SNE] Iteration 101: error = 0.9858908, gradient norm = 0.0005401
# [t-SNE] Iteration 102: error = 0.9832769, gradient norm = 0.0005328
# [t-SNE] Iteration 103: error = 0.9807179, gradient norm = 0.0005238
# [t-SNE] Iteration 104: error = 0.9782153, gradient norm = 0.0005152
# [t-SNE] Iteration 105: error = 0.9757640, gradient norm = 0.0005144
# [t-SNE] Iteration 106: error = 0.9733630, gradient norm = 0.0005217
# [t-SNE] Iteration 107: error = 0.9710082, gradient norm = 0.0005135
# [t-SNE] Iteration 108: error = 0.9686992, gradient norm = 0.0004968
# [t-SNE] Iteration 109: error = 0.9664408, gradient norm = 0.0004922
# [t-SNE] Iteration 110: error = 0.9642281, gradient norm = 0.0004796
# [t-SNE] Iteration 111: error = 0.9620573, gradient norm = 0.0004693
# [t-SNE] Iteration 112: error = 0.9599317, gradient norm = 0.0004572
# [t-SNE] Iteration 113: error = 0.9578461, gradient norm = 0.0004563
# [t-SNE] Iteration 114: error = 0.9557961, gradient norm = 0.0004605
# [t-SNE] Iteration 115: error = 0.9537780, gradient norm = 0.0004627
# [t-SNE] Iteration 116: error = 0.9517826, gradient norm = 0.0004551
# [t-SNE] Iteration 117: error = 0.9498079, gradient norm = 0.0004611
# [t-SNE] Iteration 118: error = 0.9478638, gradient norm = 0.0004604
# [t-SNE] Iteration 119: error = 0.9459768, gradient norm = 0.0004487
# [t-SNE] Iteration 120: error = 0.9441464, gradient norm = 0.0004444
# [t-SNE] Iteration 121: error = 0.9423512, gradient norm = 0.0004421
# [t-SNE] Iteration 122: error = 0.9405614, gradient norm = 0.0004594
# [t-SNE] Iteration 123: error = 0.9387529, gradient norm = 0.0004663
# [t-SNE] Iteration 124: error = 0.9369600, gradient norm = 0.0004621
# [t-SNE] Iteration 125: error = 0.9352348, gradient norm = 0.0004477
# [t-SNE] Iteration 126: error = 0.9335779, gradient norm = 0.0004444
# [t-SNE] Iteration 127: error = 0.9319601, gradient norm = 0.0004334
# [t-SNE] Iteration 128: error = 0.9303693, gradient norm = 0.0004293
# [t-SNE] Iteration 129: error = 0.9287976, gradient norm = 0.0004342
# [t-SNE] Iteration 130: error = 0.9272408, gradient norm = 0.0004179
# [t-SNE] Iteration 131: error = 0.9257048, gradient norm = 0.0004170
# [t-SNE] Iteration 132: error = 0.9241903, gradient norm = 0.0004136
# [t-SNE] Iteration 133: error = 0.9226950, gradient norm = 0.0003951
# [t-SNE] Iteration 134: error = 0.9212227, gradient norm = 0.0003928
# [t-SNE] Iteration 135: error = 0.9197720, gradient norm = 0.0003957
# [t-SNE] Iteration 136: error = 0.9183410, gradient norm = 0.0003933
# [t-SNE] Iteration 137: error = 0.9169357, gradient norm = 0.0004186
# [t-SNE] Iteration 138: error = 0.9155512, gradient norm = 0.0004290
# [t-SNE] Iteration 139: error = 0.9141814, gradient norm = 0.0003928
# [t-SNE] Iteration 140: error = 0.9128342, gradient norm = 0.0003662
# [t-SNE] Iteration 141: error = 0.9115148, gradient norm = 0.0004006
# [t-SNE] Iteration 142: error = 0.9102101, gradient norm = 0.0003912
# [t-SNE] Iteration 143: error = 0.9089213, gradient norm = 0.0003610
# [t-SNE] Iteration 144: error = 0.9076542, gradient norm = 0.0003886
# [t-SNE] Iteration 145: error = 0.9063940, gradient norm = 0.0003898
# [t-SNE] Iteration 146: error = 0.9051395, gradient norm = 0.0003548
# [t-SNE] Iteration 147: error = 0.9038965, gradient norm = 0.0003685
# [t-SNE] Iteration 148: error = 0.9026550, gradient norm = 0.0003694
# [t-SNE] Iteration 149: error = 0.9014150, gradient norm = 0.0003697
# [t-SNE] Iteration 150: error = 0.9001762, gradient norm = 0.0003656
# [t-SNE] Iteration 151: error = 0.8989401, gradient norm = 0.0003671
# [t-SNE] Iteration 152: error = 0.8977092, gradient norm = 0.0003706
# [t-SNE] Iteration 153: error = 0.8964828, gradient norm = 0.0003562
# [t-SNE] Iteration 154: error = 0.8952614, gradient norm = 0.0003589
# [t-SNE] Iteration 155: error = 0.8940438, gradient norm = 0.0003542
# [t-SNE] Iteration 156: error = 0.8928361, gradient norm = 0.0003476
# [t-SNE] Iteration 157: error = 0.8916366, gradient norm = 0.0003422
# [t-SNE] Iteration 158: error = 0.8904441, gradient norm = 0.0003445
# [t-SNE] Iteration 159: error = 0.8892619, gradient norm = 0.0003482
# [t-SNE] Iteration 160: error = 0.8880967, gradient norm = 0.0003361
# [t-SNE] Iteration 161: error = 0.8869657, gradient norm = 0.0003422
# [t-SNE] Iteration 162: error = 0.8858896, gradient norm = 0.0003466
# [t-SNE] Iteration 163: error = 0.8848673, gradient norm = 0.0003536
# [t-SNE] Iteration 164: error = 0.8838659, gradient norm = 0.0003699
# [t-SNE] Iteration 165: error = 0.8828576, gradient norm = 0.0003762
# [t-SNE] Iteration 166: error = 0.8818326, gradient norm = 0.0003652
# [t-SNE] Iteration 167: error = 0.8808084, gradient norm = 0.0003474
# [t-SNE] Iteration 168: error = 0.8797979, gradient norm = 0.0003547
# [t-SNE] Iteration 169: error = 0.8787975, gradient norm = 0.0004068
# [t-SNE] Iteration 170: error = 0.8778073, gradient norm = 0.0005154
# [t-SNE] Iteration 171: error = 0.8768217, gradient norm = 0.0006260
# [t-SNE] Iteration 172: error = 0.8758109, gradient norm = 0.0005615
# [t-SNE] Iteration 173: error = 0.8747814, gradient norm = 0.0003537
# [t-SNE] Iteration 174: error = 0.8737848, gradient norm = 0.0005421
# [t-SNE] Iteration 175: error = 0.8727345, gradient norm = 0.0003740
# [t-SNE] Iteration 176: error = 0.8716926, gradient norm = 0.0004492
# [t-SNE] Iteration 177: error = 0.8706182, gradient norm = 0.0003970
# [t-SNE] Iteration 178: error = 0.8695325, gradient norm = 0.0004217
# [t-SNE] Iteration 179: error = 0.8684170, gradient norm = 0.0003719
# [t-SNE] Iteration 180: error = 0.8672843, gradient norm = 0.0004084
# [t-SNE] Iteration 181: error = 0.8661153, gradient norm = 0.0003666
# [t-SNE] Iteration 182: error = 0.8649215, gradient norm = 0.0004136
# [t-SNE] Iteration 183: error = 0.8636827, gradient norm = 0.0003685
# [t-SNE] Iteration 184: error = 0.8624089, gradient norm = 0.0004026
# [t-SNE] Iteration 185: error = 0.8610812, gradient norm = 0.0003920
# [t-SNE] Iteration 186: error = 0.8596915, gradient norm = 0.0004075
# [t-SNE] Iteration 187: error = 0.8582188, gradient norm = 0.0004201
# [t-SNE] Iteration 188: error = 0.8566350, gradient norm = 0.0004345
# [t-SNE] Iteration 189: error = 0.8549814, gradient norm = 0.0004571
# [t-SNE] Iteration 190: error = 0.8534312, gradient norm = 0.0004703
# [t-SNE] Iteration 191: error = 0.8520263, gradient norm = 0.0005453
# [t-SNE] Iteration 192: error = 0.8506766, gradient norm = 0.0005557
# [t-SNE] Iteration 193: error = 0.8494211, gradient norm = 0.0005834
# [t-SNE] Iteration 194: error = 0.8481029, gradient norm = 0.0005335
# [t-SNE] Iteration 195: error = 0.8469725, gradient norm = 0.0004656
# [t-SNE] Iteration 196: error = 0.8463978, gradient norm = 0.0007333
# [t-SNE] Iteration 197: error = 0.8454942, gradient norm = 0.0007318
# [t-SNE] Iteration 198: error = 0.8443228, gradient norm = 0.0004815
# [t-SNE] Iteration 199: error = 0.8434810, gradient norm = 0.0004669
# [t-SNE] Iteration 200: error = 0.8428441, gradient norm = 0.0005823
# [t-SNE] Iteration 201: error = 0.8420856, gradient norm = 0.0005787
# [t-SNE] Iteration 202: error = 0.8412476, gradient norm = 0.0004784
# [t-SNE] Iteration 203: error = 0.8404840, gradient norm = 0.0004281
# [t-SNE] Iteration 204: error = 0.8397993, gradient norm = 0.0004560
# [t-SNE] Iteration 205: error = 0.8391257, gradient norm = 0.0004733
# [t-SNE] Iteration 206: error = 0.8384297, gradient norm = 0.0004463
# [t-SNE] Iteration 207: error = 0.8377233, gradient norm = 0.0003971
# [t-SNE] Iteration 208: error = 0.8370368, gradient norm = 0.0003471
# [t-SNE] Iteration 209: error = 0.8363936, gradient norm = 0.0003323
# [t-SNE] Iteration 210: error = 0.8357836, gradient norm = 0.0003519
# [t-SNE] Iteration 211: error = 0.8351804, gradient norm = 0.0003649
# [t-SNE] Iteration 212: error = 0.8345699, gradient norm = 0.0003561
# [t-SNE] Iteration 213: error = 0.8339563, gradient norm = 0.0003229
# [t-SNE] Iteration 214: error = 0.8333527, gradient norm = 0.0002971
# [t-SNE] Iteration 215: error = 0.8327652, gradient norm = 0.0002834
# [t-SNE] Iteration 216: error = 0.8321947, gradient norm = 0.0002805
# [t-SNE] Iteration 217: error = 0.8316373, gradient norm = 0.0002792
# [t-SNE] Iteration 218: error = 0.8310891, gradient norm = 0.0002733
# [t-SNE] Iteration 219: error = 0.8305511, gradient norm = 0.0002751
# [t-SNE] Iteration 220: error = 0.8300201, gradient norm = 0.0002927
# [t-SNE] Iteration 221: error = 0.8294898, gradient norm = 0.0002768
# [t-SNE] Iteration 222: error = 0.8289638, gradient norm = 0.0002536
# [t-SNE] Iteration 223: error = 0.8284457, gradient norm = 0.0002554
# [t-SNE] Iteration 224: error = 0.8279314, gradient norm = 0.0002610
# [t-SNE] Iteration 225: error = 0.8274080, gradient norm = 0.0002615
# [t-SNE] Iteration 226: error = 0.8268688, gradient norm = 0.0002579
# [t-SNE] Iteration 227: error = 0.8263857, gradient norm = 0.0002787
# [t-SNE] Iteration 228: error = 0.8258735, gradient norm = 0.0002643
# [t-SNE] Iteration 229: error = 0.8253807, gradient norm = 0.0002634
# [t-SNE] Iteration 230: error = 0.8248950, gradient norm = 0.0002705
# [t-SNE] Iteration 231: error = 0.8243924, gradient norm = 0.0002587
# [t-SNE] Iteration 232: error = 0.8238913, gradient norm = 0.0002432
# [t-SNE] Iteration 233: error = 0.8234001, gradient norm = 0.0002449
# [t-SNE] Iteration 234: error = 0.8229044, gradient norm = 0.0002378
# [t-SNE] Iteration 235: error = 0.8224060, gradient norm = 0.0002319
# [t-SNE] Iteration 236: error = 0.8219083, gradient norm = 0.0002327
# [t-SNE] Iteration 237: error = 0.8214106, gradient norm = 0.0002398
# [t-SNE] Iteration 238: error = 0.8209104, gradient norm = 0.0002329
# [t-SNE] Iteration 239: error = 0.8204072, gradient norm = 0.0002275
# [t-SNE] Iteration 240: error = 0.8199024, gradient norm = 0.0002258
# [t-SNE] Iteration 241: error = 0.8193970, gradient norm = 0.0002324
# [t-SNE] Iteration 242: error = 0.8188895, gradient norm = 0.0002417
# [t-SNE] Iteration 243: error = 0.8183783, gradient norm = 0.0002533
# [t-SNE] Iteration 244: error = 0.8178609, gradient norm = 0.0002606
# [t-SNE] Iteration 245: error = 0.8173382, gradient norm = 0.0002519
# [t-SNE] Iteration 246: error = 0.8168143, gradient norm = 0.0002481
# [t-SNE] Iteration 247: error = 0.8162881, gradient norm = 0.0002466
# [t-SNE] Iteration 248: error = 0.8157604, gradient norm = 0.0002480
# [t-SNE] Iteration 249: error = 0.8152327, gradient norm = 0.0002427
# [t-SNE] Iteration 250: error = 0.8147044, gradient norm = 0.0002398
# [t-SNE] Iteration 251: error = 0.8141765, gradient norm = 0.0002561
# [t-SNE] Iteration 252: error = 0.8136420, gradient norm = 0.0002609
# [t-SNE] Iteration 253: error = 0.8130945, gradient norm = 0.0002528
# [t-SNE] Iteration 254: error = 0.8125265, gradient norm = 0.0002664
# [t-SNE] Iteration 255: error = 0.8119288, gradient norm = 0.0002796
# [t-SNE] Iteration 256: error = 0.8113272, gradient norm = 0.0002518
# [t-SNE] Iteration 257: error = 0.8108733, gradient norm = 0.0002765
# [t-SNE] Iteration 258: error = 0.8104263, gradient norm = 0.0002812
# [t-SNE] Iteration 259: error = 0.8099404, gradient norm = 0.0002991
# [t-SNE] Iteration 260: error = 0.8094415, gradient norm = 0.0002932
# [t-SNE] Iteration 261: error = 0.8089286, gradient norm = 0.0002758
# [t-SNE] Iteration 262: error = 0.8084005, gradient norm = 0.0002621
# [t-SNE] Iteration 263: error = 0.8078600, gradient norm = 0.0002675
# [t-SNE] Iteration 264: error = 0.8072964, gradient norm = 0.0002795
# [t-SNE] Iteration 265: error = 0.8067308, gradient norm = 0.0002755
# [t-SNE] Iteration 266: error = 0.8062190, gradient norm = 0.0002918
# [t-SNE] Iteration 267: error = 0.8057102, gradient norm = 0.0002977
# [t-SNE] Iteration 268: error = 0.8051957, gradient norm = 0.0003028
# [t-SNE] Iteration 269: error = 0.8046650, gradient norm = 0.0002963
# [t-SNE] Iteration 270: error = 0.8041207, gradient norm = 0.0002788
# [t-SNE] Iteration 271: error = 0.8035742, gradient norm = 0.0002699
# [t-SNE] Iteration 272: error = 0.8030243, gradient norm = 0.0002595
# [t-SNE] Iteration 273: error = 0.8024716, gradient norm = 0.0002482
# [t-SNE] Iteration 274: error = 0.8019120, gradient norm = 0.0002574
# [t-SNE] Iteration 275: error = 0.8013379, gradient norm = 0.0002614
# [t-SNE] Iteration 276: error = 0.8007464, gradient norm = 0.0002562
# [t-SNE] Iteration 277: error = 0.8001375, gradient norm = 0.0002579
# [t-SNE] Iteration 278: error = 0.7995094, gradient norm = 0.0002381
# [t-SNE] Iteration 279: error = 0.7988628, gradient norm = 0.0002378
# [t-SNE] Iteration 280: error = 0.7981936, gradient norm = 0.0002510
# [t-SNE] Iteration 281: error = 0.7974966, gradient norm = 0.0002452
# [t-SNE] Iteration 282: error = 0.7967696, gradient norm = 0.0002530
# [t-SNE] Iteration 283: error = 0.7960075, gradient norm = 0.0002585
# [t-SNE] Iteration 284: error = 0.7952073, gradient norm = 0.0002656
# [t-SNE] Iteration 285: error = 0.7943633, gradient norm = 0.0002735
# [t-SNE] Iteration 286: error = 0.7934681, gradient norm = 0.0002723
# [t-SNE] Iteration 287: error = 0.7925162, gradient norm = 0.0002753
# [t-SNE] Iteration 288: error = 0.7915021, gradient norm = 0.0002771
# [t-SNE] Iteration 289: error = 0.7904229, gradient norm = 0.0002782
# [t-SNE] Iteration 290: error = 0.7892853, gradient norm = 0.0002842
# [t-SNE] Iteration 291: error = 0.7881281, gradient norm = 0.0002734
# [t-SNE] Iteration 292: error = 0.7871077, gradient norm = 0.0002724
# [t-SNE] Iteration 293: error = 0.7864136, gradient norm = 0.0003944
# [t-SNE] Iteration 294: error = 0.7856815, gradient norm = 0.0003651
# [t-SNE] Iteration 295: error = 0.7850588, gradient norm = 0.0003338
# [t-SNE] Iteration 296: error = 0.7845675, gradient norm = 0.0003670
# [t-SNE] Iteration 297: error = 0.7842519, gradient norm = 0.0003782
# [t-SNE] Iteration 298: error = 0.7840006, gradient norm = 0.0004159
# [t-SNE] Iteration 299: error = 0.7835853, gradient norm = 0.0003961
# [t-SNE] Iteration 300: error = 0.7831602, gradient norm = 0.0003671
# [t-SNE] Iteration 301: error = 0.7827645, gradient norm = 0.0003338
# [t-SNE] Iteration 302: error = 0.7824479, gradient norm = 0.0003562
# [t-SNE] Iteration 303: error = 0.7820733, gradient norm = 0.0003260
# [t-SNE] Iteration 304: error = 0.7816963, gradient norm = 0.0003016
# [t-SNE] Iteration 305: error = 0.7813431, gradient norm = 0.0002955
# [t-SNE] Iteration 306: error = 0.7809896, gradient norm = 0.0002845
# [t-SNE] Iteration 307: error = 0.7806344, gradient norm = 0.0002610
# [t-SNE] Iteration 308: error = 0.7802907, gradient norm = 0.0002345
# [t-SNE] Iteration 309: error = 0.7799651, gradient norm = 0.0002278
# [t-SNE] Iteration 310: error = 0.7796510, gradient norm = 0.0002173
# [t-SNE] Iteration 311: error = 0.7793449, gradient norm = 0.0002246
# [t-SNE] Iteration 312: error = 0.7790407, gradient norm = 0.0002189
# [t-SNE] Iteration 313: error = 0.7787356, gradient norm = 0.0002062
# [t-SNE] Iteration 314: error = 0.7784315, gradient norm = 0.0001991
# [t-SNE] Iteration 315: error = 0.7781300, gradient norm = 0.0001875
# [t-SNE] Iteration 316: error = 0.7778334, gradient norm = 0.0001806
# [t-SNE] Iteration 317: error = 0.7775415, gradient norm = 0.0001787
# [t-SNE] Iteration 318: error = 0.7772533, gradient norm = 0.0001805
# [t-SNE] Iteration 319: error = 0.7769677, gradient norm = 0.0001804
# [t-SNE] Iteration 320: error = 0.7766841, gradient norm = 0.0001737
# [t-SNE] Iteration 321: error = 0.7764031, gradient norm = 0.0001693
# [t-SNE] Iteration 322: error = 0.7761248, gradient norm = 0.0001678
# [t-SNE] Iteration 323: error = 0.7758491, gradient norm = 0.0001697
# [t-SNE] Iteration 324: error = 0.7755762, gradient norm = 0.0001687
# [t-SNE] Iteration 325: error = 0.7753062, gradient norm = 0.0001594
# [t-SNE] Iteration 326: error = 0.7750390, gradient norm = 0.0001494
# [t-SNE] Iteration 327: error = 0.7747758, gradient norm = 0.0001563
# [t-SNE] Iteration 328: error = 0.7745153, gradient norm = 0.0001629
# [t-SNE] Iteration 329: error = 0.7742572, gradient norm = 0.0001549
# [t-SNE] Iteration 330: error = 0.7740018, gradient norm = 0.0001528
# [t-SNE] Iteration 331: error = 0.7737486, gradient norm = 0.0001472
# [t-SNE] Iteration 332: error = 0.7734976, gradient norm = 0.0001553
# [t-SNE] Iteration 333: error = 0.7732466, gradient norm = 0.0001649
# [t-SNE] Iteration 334: error = 0.7729942, gradient norm = 0.0001693
# [t-SNE] Iteration 335: error = 0.7727392, gradient norm = 0.0001785
# [t-SNE] Iteration 336: error = 0.7724807, gradient norm = 0.0001751
# [t-SNE] Iteration 337: error = 0.7722274, gradient norm = 0.0001663
# [t-SNE] Iteration 338: error = 0.7719874, gradient norm = 0.0001746
# [t-SNE] Iteration 339: error = 0.7717596, gradient norm = 0.0001940
# [t-SNE] Iteration 340: error = 0.7715380, gradient norm = 0.0001828
# [t-SNE] Iteration 341: error = 0.7713177, gradient norm = 0.0001666
# [t-SNE] Iteration 342: error = 0.7710966, gradient norm = 0.0001833
# [t-SNE] Iteration 343: error = 0.7708720, gradient norm = 0.0001577
# [t-SNE] Iteration 344: error = 0.7706494, gradient norm = 0.0001693
# [t-SNE] Iteration 345: error = 0.7704281, gradient norm = 0.0001648
# [t-SNE] Iteration 346: error = 0.7702082, gradient norm = 0.0001532
# [t-SNE] Iteration 347: error = 0.7699900, gradient norm = 0.0001558
# [t-SNE] Iteration 348: error = 0.7697720, gradient norm = 0.0001400
# [t-SNE] Iteration 349: error = 0.7695564, gradient norm = 0.0001501
# [t-SNE] Iteration 350: error = 0.7693425, gradient norm = 0.0001499
# [t-SNE] Iteration 351: error = 0.7691299, gradient norm = 0.0001423
# [t-SNE] Iteration 352: error = 0.7689190, gradient norm = 0.0001442
# [t-SNE] Iteration 353: error = 0.7687090, gradient norm = 0.0001431
# [t-SNE] Iteration 354: error = 0.7684994, gradient norm = 0.0001425
# [t-SNE] Iteration 355: error = 0.7682900, gradient norm = 0.0001341
# [t-SNE] Iteration 356: error = 0.7680815, gradient norm = 0.0001358
# [t-SNE] Iteration 357: error = 0.7678732, gradient norm = 0.0001326
# [t-SNE] Iteration 358: error = 0.7676654, gradient norm = 0.0001286
# [t-SNE] Iteration 359: error = 0.7674583, gradient norm = 0.0001365
# [t-SNE] Iteration 360: error = 0.7672507, gradient norm = 0.0001319
# [t-SNE] Iteration 361: error = 0.7670430, gradient norm = 0.0001323
# [t-SNE] Iteration 362: error = 0.7668346, gradient norm = 0.0001290
# [t-SNE] Iteration 363: error = 0.7666248, gradient norm = 0.0001302
# [t-SNE] Iteration 364: error = 0.7664126, gradient norm = 0.0001333
# [t-SNE] Iteration 365: error = 0.7661967, gradient norm = 0.0001290
# [t-SNE] Iteration 366: error = 0.7659776, gradient norm = 0.0001317
# [t-SNE] Iteration 367: error = 0.7657561, gradient norm = 0.0001319
# [t-SNE] Iteration 368: error = 0.7655342, gradient norm = 0.0001292
# [t-SNE] Iteration 369: error = 0.7653136, gradient norm = 0.0001333
# [t-SNE] Iteration 370: error = 0.7650936, gradient norm = 0.0001310
# [t-SNE] Iteration 371: error = 0.7648734, gradient norm = 0.0001338
# [t-SNE] Iteration 372: error = 0.7646518, gradient norm = 0.0001427
# [t-SNE] Iteration 373: error = 0.7644276, gradient norm = 0.0001592
# [t-SNE] Iteration 374: error = 0.7641999, gradient norm = 0.0001758
# [t-SNE] Iteration 375: error = 0.7639650, gradient norm = 0.0001680
# [t-SNE] Iteration 376: error = 0.7637191, gradient norm = 0.0001480
# [t-SNE] Iteration 377: error = 0.7634556, gradient norm = 0.0001660
# [t-SNE] Iteration 378: error = 0.7631546, gradient norm = 0.0002010
# [t-SNE] Iteration 379: error = 0.7627690, gradient norm = 0.0002351
# [t-SNE] Iteration 380: error = 0.7623979, gradient norm = 0.0001959
# [t-SNE] Iteration 381: error = 0.7623552, gradient norm = 0.0002992
# [t-SNE] Iteration 382: error = 0.7622363, gradient norm = 0.0003255
# [t-SNE] Iteration 383: error = 0.7619253, gradient norm = 0.0002605
# [t-SNE] Iteration 384: error = 0.7616396, gradient norm = 0.0001491
# [t-SNE] Iteration 385: error = 0.7614792, gradient norm = 0.0001980
# [t-SNE] Iteration 386: error = 0.7613648, gradient norm = 0.0002309
# [t-SNE] Iteration 387: error = 0.7611936, gradient norm = 0.0002291
# [t-SNE] Iteration 388: error = 0.7609852, gradient norm = 0.0002241
# [t-SNE] Iteration 389: error = 0.7607527, gradient norm = 0.0001848
# [t-SNE] Iteration 390: error = 0.7605459, gradient norm = 0.0001289
# [t-SNE] Iteration 391: error = 0.7603908, gradient norm = 0.0001531
# [t-SNE] Iteration 392: error = 0.7602389, gradient norm = 0.0001635
# [t-SNE] Iteration 393: error = 0.7600764, gradient norm = 0.0001505
# [t-SNE] Iteration 394: error = 0.7599106, gradient norm = 0.0001429
# [t-SNE] Iteration 395: error = 0.7597451, gradient norm = 0.0001383
# [t-SNE] Iteration 396: error = 0.7595800, gradient norm = 0.0001400
# [t-SNE] Iteration 397: error = 0.7594137, gradient norm = 0.0001414
# [t-SNE] Iteration 398: error = 0.7592455, gradient norm = 0.0001429
# [t-SNE] Iteration 399: error = 0.7590770, gradient norm = 0.0001314
# [t-SNE] Iteration 400: error = 0.7589123, gradient norm = 0.0001201
# [t-SNE] Iteration 401: error = 0.7587540, gradient norm = 0.0001247
# [t-SNE] Iteration 402: error = 0.7586000, gradient norm = 0.0001273
# [t-SNE] Iteration 403: error = 0.7584471, gradient norm = 0.0001270
# [t-SNE] Iteration 404: error = 0.7582946, gradient norm = 0.0001245
# [t-SNE] Iteration 405: error = 0.7581432, gradient norm = 0.0001236
# [t-SNE] Iteration 406: error = 0.7579927, gradient norm = 0.0001215
# [t-SNE] Iteration 407: error = 0.7578430, gradient norm = 0.0001193
# [t-SNE] Iteration 408: error = 0.7576943, gradient norm = 0.0001158
# [t-SNE] Iteration 409: error = 0.7575464, gradient norm = 0.0001125
# [t-SNE] Iteration 410: error = 0.7573996, gradient norm = 0.0001126
# [t-SNE] Iteration 411: error = 0.7572541, gradient norm = 0.0001090
# [t-SNE] Iteration 412: error = 0.7571099, gradient norm = 0.0001071
# [t-SNE] Iteration 413: error = 0.7569673, gradient norm = 0.0001186
# [t-SNE] Iteration 414: error = 0.7568261, gradient norm = 0.0001383
# [t-SNE] Iteration 415: error = 0.7566846, gradient norm = 0.0001411
# [t-SNE] Iteration 416: error = 0.7565426, gradient norm = 0.0001130
# [t-SNE] Iteration 417: error = 0.7564017, gradient norm = 0.0001071
# [t-SNE] Iteration 418: error = 0.7562618, gradient norm = 0.0001244
# [t-SNE] Iteration 419: error = 0.7561217, gradient norm = 0.0001085
# [t-SNE] Iteration 420: error = 0.7559842, gradient norm = 0.0001231
# [t-SNE] Iteration 421: error = 0.7558484, gradient norm = 0.0001285
# [t-SNE] Iteration 422: error = 0.7557131, gradient norm = 0.0001099
# [t-SNE] Iteration 423: error = 0.7555787, gradient norm = 0.0001041
# [t-SNE] Iteration 424: error = 0.7554450, gradient norm = 0.0001069
# [t-SNE] Iteration 425: error = 0.7553121, gradient norm = 0.0001137
# [t-SNE] Iteration 426: error = 0.7551793, gradient norm = 0.0001013
# [t-SNE] Iteration 427: error = 0.7550477, gradient norm = 0.0001121
# [t-SNE] Iteration 428: error = 0.7549171, gradient norm = 0.0001234
# [t-SNE] Iteration 429: error = 0.7547868, gradient norm = 0.0001244
# [t-SNE] Iteration 430: error = 0.7546569, gradient norm = 0.0001152
# [t-SNE] Iteration 431: error = 0.7545277, gradient norm = 0.0000996
# [t-SNE] Iteration 432: error = 0.7544001, gradient norm = 0.0001089
# [t-SNE] Iteration 433: error = 0.7542728, gradient norm = 0.0000997
# [t-SNE] Iteration 434: error = 0.7541466, gradient norm = 0.0001043
# [t-SNE] Iteration 435: error = 0.7540209, gradient norm = 0.0001047
# [t-SNE] Iteration 436: error = 0.7538963, gradient norm = 0.0001163
# [t-SNE] Iteration 437: error = 0.7537730, gradient norm = 0.0001474
# [t-SNE] Iteration 438: error = 0.7536497, gradient norm = 0.0001557
# [t-SNE] Iteration 439: error = 0.7535255, gradient norm = 0.0001248
# [t-SNE] Iteration 440: error = 0.7534024, gradient norm = 0.0000929
# [t-SNE] Iteration 441: error = 0.7532816, gradient norm = 0.0001226
# [t-SNE] Iteration 442: error = 0.7531605, gradient norm = 0.0001191
# [t-SNE] Iteration 443: error = 0.7530398, gradient norm = 0.0001042
# [t-SNE] Iteration 444: error = 0.7529208, gradient norm = 0.0001231
# [t-SNE] Iteration 445: error = 0.7528014, gradient norm = 0.0001083
# [t-SNE] Iteration 446: error = 0.7526828, gradient norm = 0.0000944
# [t-SNE] Iteration 447: error = 0.7525655, gradient norm = 0.0001065
# [t-SNE] Iteration 448: error = 0.7524485, gradient norm = 0.0000996
# [t-SNE] Iteration 449: error = 0.7523322, gradient norm = 0.0000995
# [t-SNE] Iteration 450: error = 0.7522164, gradient norm = 0.0000929
# [t-SNE] Iteration 451: error = 0.7521014, gradient norm = 0.0000979
# [t-SNE] Iteration 452: error = 0.7519869, gradient norm = 0.0000911
# [t-SNE] Iteration 453: error = 0.7518730, gradient norm = 0.0000945
# [t-SNE] Iteration 454: error = 0.7517595, gradient norm = 0.0000883
# [t-SNE] Iteration 455: error = 0.7516468, gradient norm = 0.0000902
# [t-SNE] Iteration 456: error = 0.7515347, gradient norm = 0.0000949
# [t-SNE] Iteration 457: error = 0.7514228, gradient norm = 0.0000905
# [t-SNE] Iteration 458: error = 0.7513117, gradient norm = 0.0001016
# [t-SNE] Iteration 459: error = 0.7512009, gradient norm = 0.0001056
# [t-SNE] Iteration 460: error = 0.7510906, gradient norm = 0.0001066
# [t-SNE] Iteration 461: error = 0.7509803, gradient norm = 0.0000876
# [t-SNE] Iteration 462: error = 0.7508709, gradient norm = 0.0000871
# [t-SNE] Iteration 463: error = 0.7507621, gradient norm = 0.0000971
# [t-SNE] Iteration 464: error = 0.7506531, gradient norm = 0.0000861
# [t-SNE] Iteration 465: error = 0.7505448, gradient norm = 0.0000917
# [t-SNE] Iteration 466: error = 0.7504369, gradient norm = 0.0000938
# [t-SNE] Iteration 467: error = 0.7503289, gradient norm = 0.0000885
# [t-SNE] Iteration 468: error = 0.7502213, gradient norm = 0.0000862
# [t-SNE] Iteration 469: error = 0.7501142, gradient norm = 0.0000883
# [t-SNE] Iteration 470: error = 0.7500074, gradient norm = 0.0000927
# [t-SNE] Iteration 471: error = 0.7499009, gradient norm = 0.0000903
# [t-SNE] Iteration 472: error = 0.7497949, gradient norm = 0.0000933
# [t-SNE] Iteration 473: error = 0.7496889, gradient norm = 0.0000873
# [t-SNE] Iteration 474: error = 0.7495836, gradient norm = 0.0000898
# [t-SNE] Iteration 475: error = 0.7494787, gradient norm = 0.0000901
# [t-SNE] Iteration 476: error = 0.7493740, gradient norm = 0.0000926
# [t-SNE] Iteration 477: error = 0.7492697, gradient norm = 0.0000870
# [t-SNE] Iteration 478: error = 0.7491661, gradient norm = 0.0000878
# [t-SNE] Iteration 479: error = 0.7490631, gradient norm = 0.0000902
# [t-SNE] Iteration 480: error = 0.7489604, gradient norm = 0.0000897
# [t-SNE] Iteration 481: error = 0.7488582, gradient norm = 0.0000877
# [t-SNE] Iteration 482: error = 0.7487564, gradient norm = 0.0000856
# [t-SNE] Iteration 483: error = 0.7486552, gradient norm = 0.0000830
# [t-SNE] Iteration 484: error = 0.7485545, gradient norm = 0.0000842
# [t-SNE] Iteration 485: error = 0.7484541, gradient norm = 0.0000843
# [t-SNE] Iteration 486: error = 0.7483543, gradient norm = 0.0000821
# [t-SNE] Iteration 487: error = 0.7482547, gradient norm = 0.0000820
# [t-SNE] Iteration 488: error = 0.7481554, gradient norm = 0.0000829
# [t-SNE] Iteration 489: error = 0.7480565, gradient norm = 0.0000818
# [t-SNE] Iteration 490: error = 0.7479578, gradient norm = 0.0000797
# [t-SNE] Iteration 491: error = 0.7478594, gradient norm = 0.0000841
# [t-SNE] Iteration 492: error = 0.7477612, gradient norm = 0.0000845
# [t-SNE] Iteration 493: error = 0.7476632, gradient norm = 0.0000832
# [t-SNE] Iteration 494: error = 0.7475654, gradient norm = 0.0000810
# [t-SNE] Iteration 495: error = 0.7474680, gradient norm = 0.0000831
# [t-SNE] Iteration 496: error = 0.7473708, gradient norm = 0.0000852
# [t-SNE] Iteration 497: error = 0.7472740, gradient norm = 0.0000874
# [t-SNE] Iteration 498: error = 0.7471776, gradient norm = 0.0000890
# [t-SNE] Iteration 499: error = 0.7470815, gradient norm = 0.0000815
# [t-SNE] Iteration 500: error = 0.7469859, gradient norm = 0.0000796
# [t-SNE] Iteration 501: error = 0.7468909, gradient norm = 0.0000880
# [t-SNE] Iteration 502: error = 0.7467963, gradient norm = 0.0000865
# [t-SNE] Iteration 503: error = 0.7467020, gradient norm = 0.0000819
# [t-SNE] Iteration 504: error = 0.7466082, gradient norm = 0.0000803
# [t-SNE] Iteration 505: error = 0.7465148, gradient norm = 0.0000787
# [t-SNE] Iteration 506: error = 0.7464219, gradient norm = 0.0000796
# [t-SNE] Iteration 507: error = 0.7463294, gradient norm = 0.0000792
# [t-SNE] Iteration 508: error = 0.7462371, gradient norm = 0.0000801
# [t-SNE] Iteration 509: error = 0.7461451, gradient norm = 0.0000779
# [t-SNE] Iteration 510: error = 0.7460533, gradient norm = 0.0000745
# [t-SNE] Iteration 511: error = 0.7459618, gradient norm = 0.0000785
# [t-SNE] Iteration 512: error = 0.7458703, gradient norm = 0.0000761
# [t-SNE] Iteration 513: error = 0.7457793, gradient norm = 0.0000797
# [t-SNE] Iteration 514: error = 0.7456885, gradient norm = 0.0000821
# [t-SNE] Iteration 515: error = 0.7455978, gradient norm = 0.0000819
# [t-SNE] Iteration 516: error = 0.7455078, gradient norm = 0.0000873
# [t-SNE] Iteration 517: error = 0.7454184, gradient norm = 0.0001014
# [t-SNE] Iteration 518: error = 0.7453294, gradient norm = 0.0001100
# [t-SNE] Iteration 519: error = 0.7452405, gradient norm = 0.0001159
# [t-SNE] Iteration 520: error = 0.7451514, gradient norm = 0.0000952
# [t-SNE] Iteration 521: error = 0.7450629, gradient norm = 0.0000794
# [t-SNE] Iteration 522: error = 0.7449756, gradient norm = 0.0000984
# [t-SNE] Iteration 523: error = 0.7448878, gradient norm = 0.0000851
# [t-SNE] Iteration 524: error = 0.7448006, gradient norm = 0.0000775
# [t-SNE] Iteration 525: error = 0.7447140, gradient norm = 0.0000866
# [t-SNE] Iteration 526: error = 0.7446274, gradient norm = 0.0000823
# [t-SNE] Iteration 527: error = 0.7445413, gradient norm = 0.0000822
# [t-SNE] Iteration 528: error = 0.7444559, gradient norm = 0.0000928
# [t-SNE] Iteration 529: error = 0.7443705, gradient norm = 0.0000914
# [t-SNE] Iteration 530: error = 0.7442854, gradient norm = 0.0000870
# [t-SNE] Iteration 531: error = 0.7442005, gradient norm = 0.0000769
# [t-SNE] Iteration 532: error = 0.7441164, gradient norm = 0.0000871
# [t-SNE] Iteration 533: error = 0.7440322, gradient norm = 0.0000794
# [t-SNE] Iteration 534: error = 0.7439484, gradient norm = 0.0000732
# [t-SNE] Iteration 535: error = 0.7438652, gradient norm = 0.0000812
# [t-SNE] Iteration 536: error = 0.7437820, gradient norm = 0.0000784
# [t-SNE] Iteration 537: error = 0.7436990, gradient norm = 0.0000766
# [t-SNE] Iteration 538: error = 0.7436163, gradient norm = 0.0000775
# [t-SNE] Iteration 539: error = 0.7435338, gradient norm = 0.0000735
# [t-SNE] Iteration 540: error = 0.7434516, gradient norm = 0.0000772
# [t-SNE] Iteration 541: error = 0.7433694, gradient norm = 0.0000746
# [t-SNE] Iteration 542: error = 0.7432874, gradient norm = 0.0000722
# [t-SNE] Iteration 543: error = 0.7432058, gradient norm = 0.0000725
# [t-SNE] Iteration 544: error = 0.7431244, gradient norm = 0.0000745
# [t-SNE] Iteration 545: error = 0.7430430, gradient norm = 0.0000745
# [t-SNE] Iteration 546: error = 0.7429619, gradient norm = 0.0000744
# [t-SNE] Iteration 547: error = 0.7428812, gradient norm = 0.0000817
# [t-SNE] Iteration 548: error = 0.7428005, gradient norm = 0.0000811
# [t-SNE] Iteration 549: error = 0.7427197, gradient norm = 0.0000730
# [t-SNE] Iteration 550: error = 0.7426394, gradient norm = 0.0000701
# [t-SNE] Iteration 551: error = 0.7425595, gradient norm = 0.0000727
# [t-SNE] Iteration 552: error = 0.7424796, gradient norm = 0.0000739
# [t-SNE] Iteration 553: error = 0.7423999, gradient norm = 0.0000773
# [t-SNE] Iteration 554: error = 0.7423204, gradient norm = 0.0000770
# [t-SNE] Iteration 555: error = 0.7422413, gradient norm = 0.0000748
# [t-SNE] Iteration 556: error = 0.7421623, gradient norm = 0.0000725
# [t-SNE] Iteration 557: error = 0.7420837, gradient norm = 0.0000729
# [t-SNE] Iteration 558: error = 0.7420053, gradient norm = 0.0000743
# [t-SNE] Iteration 559: error = 0.7419272, gradient norm = 0.0000787
# [t-SNE] Iteration 560: error = 0.7418491, gradient norm = 0.0000740
# [t-SNE] Iteration 561: error = 0.7417713, gradient norm = 0.0000755
# [t-SNE] Iteration 562: error = 0.7416937, gradient norm = 0.0000783
# [t-SNE] Iteration 563: error = 0.7416160, gradient norm = 0.0000762
# [t-SNE] Iteration 564: error = 0.7415385, gradient norm = 0.0000738
# [t-SNE] Iteration 565: error = 0.7414611, gradient norm = 0.0000741
# [t-SNE] Iteration 566: error = 0.7413838, gradient norm = 0.0000741
# [t-SNE] Iteration 567: error = 0.7413066, gradient norm = 0.0000733
# [t-SNE] Iteration 568: error = 0.7412294, gradient norm = 0.0000704
# [t-SNE] Iteration 569: error = 0.7411522, gradient norm = 0.0000696
# [t-SNE] Iteration 570: error = 0.7410750, gradient norm = 0.0000719
# [t-SNE] Iteration 571: error = 0.7409976, gradient norm = 0.0000717
# [t-SNE] Iteration 572: error = 0.7409199, gradient norm = 0.0000751
# [t-SNE] Iteration 573: error = 0.7408419, gradient norm = 0.0000701
# [t-SNE] Iteration 574: error = 0.7407636, gradient norm = 0.0000693
# [t-SNE] Iteration 575: error = 0.7406851, gradient norm = 0.0000694
# [t-SNE] Iteration 576: error = 0.7406064, gradient norm = 0.0000692
# [t-SNE] Iteration 577: error = 0.7405274, gradient norm = 0.0000725
# [t-SNE] Iteration 578: error = 0.7404482, gradient norm = 0.0000687
# [t-SNE] Iteration 579: error = 0.7403690, gradient norm = 0.0000709
# [t-SNE] Iteration 580: error = 0.7402900, gradient norm = 0.0000722
# [t-SNE] Iteration 581: error = 0.7402112, gradient norm = 0.0000721
# [t-SNE] Iteration 582: error = 0.7401326, gradient norm = 0.0000690
# [t-SNE] Iteration 583: error = 0.7400546, gradient norm = 0.0000703
# [t-SNE] Iteration 584: error = 0.7399768, gradient norm = 0.0000737
# [t-SNE] Iteration 585: error = 0.7398992, gradient norm = 0.0000736
# [t-SNE] Iteration 586: error = 0.7398214, gradient norm = 0.0000699
# [t-SNE] Iteration 587: error = 0.7397437, gradient norm = 0.0000727
# [t-SNE] Iteration 588: error = 0.7396656, gradient norm = 0.0000729
# [t-SNE] Iteration 589: error = 0.7395872, gradient norm = 0.0000733
# [t-SNE] Iteration 590: error = 0.7395084, gradient norm = 0.0000734
# [t-SNE] Iteration 591: error = 0.7394291, gradient norm = 0.0000719
# [t-SNE] Iteration 592: error = 0.7393491, gradient norm = 0.0000747
# [t-SNE] Iteration 593: error = 0.7392683, gradient norm = 0.0000748
# [t-SNE] Iteration 594: error = 0.7391865, gradient norm = 0.0000718
# [t-SNE] Iteration 595: error = 0.7391035, gradient norm = 0.0000726
# [t-SNE] Iteration 596: error = 0.7390189, gradient norm = 0.0000715
# [t-SNE] Iteration 597: error = 0.7389327, gradient norm = 0.0000732
# [t-SNE] Iteration 598: error = 0.7388453, gradient norm = 0.0000714
# [t-SNE] Iteration 599: error = 0.7387574, gradient norm = 0.0000712
# [t-SNE] Iteration 600: error = 0.7386706, gradient norm = 0.0000690
# [t-SNE] Iteration 601: error = 0.7385862, gradient norm = 0.0000710
# [t-SNE] Iteration 602: error = 0.7385034, gradient norm = 0.0000715
# [t-SNE] Iteration 603: error = 0.7384212, gradient norm = 0.0000717
# [t-SNE] Iteration 604: error = 0.7383399, gradient norm = 0.0000765
# [t-SNE] Iteration 605: error = 0.7382602, gradient norm = 0.0000830
# [t-SNE] Iteration 606: error = 0.7381825, gradient norm = 0.0000885
# [t-SNE] Iteration 607: error = 0.7381070, gradient norm = 0.0000810
# [t-SNE] Iteration 608: error = 0.7380339, gradient norm = 0.0000729
# [t-SNE] Iteration 609: error = 0.7379631, gradient norm = 0.0000752
# [t-SNE] Iteration 610: error = 0.7378936, gradient norm = 0.0000730
# [t-SNE] Iteration 611: error = 0.7378242, gradient norm = 0.0000696
# [t-SNE] Iteration 612: error = 0.7377547, gradient norm = 0.0000737
# [t-SNE] Iteration 613: error = 0.7376846, gradient norm = 0.0000684
# [t-SNE] Iteration 614: error = 0.7376146, gradient norm = 0.0000698
# [t-SNE] Iteration 615: error = 0.7375449, gradient norm = 0.0000725
# [t-SNE] Iteration 616: error = 0.7374754, gradient norm = 0.0000805
# [t-SNE] Iteration 617: error = 0.7374069, gradient norm = 0.0001053
# [t-SNE] Iteration 618: error = 0.7373384, gradient norm = 0.0001213
# [t-SNE] Iteration 619: error = 0.7372693, gradient norm = 0.0001029
# [t-SNE] Iteration 620: error = 0.7372002, gradient norm = 0.0000646
# [t-SNE] Iteration 621: error = 0.7371325, gradient norm = 0.0000851
# [t-SNE] Iteration 622: error = 0.7370648, gradient norm = 0.0000908
# [t-SNE] Iteration 623: error = 0.7369965, gradient norm = 0.0000671
# [t-SNE] Iteration 624: error = 0.7369290, gradient norm = 0.0000803
# [t-SNE] Iteration 625: error = 0.7368613, gradient norm = 0.0000823
# [t-SNE] Iteration 626: error = 0.7367930, gradient norm = 0.0000675
# [t-SNE] Iteration 627: error = 0.7367254, gradient norm = 0.0000781
# [t-SNE] Iteration 628: error = 0.7366581, gradient norm = 0.0000683
# [t-SNE] Iteration 629: error = 0.7365918, gradient norm = 0.0000711
# [t-SNE] Iteration 630: error = 0.7365257, gradient norm = 0.0000716
# [t-SNE] Iteration 631: error = 0.7364597, gradient norm = 0.0000735
# [t-SNE] Iteration 632: error = 0.7363939, gradient norm = 0.0000726
# [t-SNE] Iteration 633: error = 0.7363285, gradient norm = 0.0000703
# [t-SNE] Iteration 634: error = 0.7362635, gradient norm = 0.0000686
# [t-SNE] Iteration 635: error = 0.7361987, gradient norm = 0.0000719
# [t-SNE] Iteration 636: error = 0.7361341, gradient norm = 0.0000758
# [t-SNE] Iteration 637: error = 0.7360700, gradient norm = 0.0000975
# [t-SNE] Iteration 638: error = 0.7360058, gradient norm = 0.0001059
# [t-SNE] Iteration 639: error = 0.7359411, gradient norm = 0.0000892
# [t-SNE] Iteration 640: error = 0.7358764, gradient norm = 0.0000651
# [t-SNE] Iteration 641: error = 0.7358127, gradient norm = 0.0000806
# [t-SNE] Iteration 642: error = 0.7357488, gradient norm = 0.0000818
# [t-SNE] Iteration 643: error = 0.7356847, gradient norm = 0.0000644
# [t-SNE] Iteration 644: error = 0.7356212, gradient norm = 0.0000731
# [t-SNE] Iteration 645: error = 0.7355576, gradient norm = 0.0000731
# [t-SNE] Iteration 646: error = 0.7354942, gradient norm = 0.0000730
# [t-SNE] Iteration 647: error = 0.7354311, gradient norm = 0.0000876
# [t-SNE] Iteration 648: error = 0.7353678, gradient norm = 0.0000810
# [t-SNE] Iteration 649: error = 0.7353044, gradient norm = 0.0000723
# [t-SNE] Iteration 650: error = 0.7352414, gradient norm = 0.0000677
# [t-SNE] Iteration 651: error = 0.7351788, gradient norm = 0.0000801
# [t-SNE] Iteration 652: error = 0.7351158, gradient norm = 0.0000688
# [t-SNE] Iteration 653: error = 0.7350533, gradient norm = 0.0000756
# [t-SNE] Iteration 654: error = 0.7349906, gradient norm = 0.0000723
# [t-SNE] Iteration 655: error = 0.7349280, gradient norm = 0.0000662
# [t-SNE] Iteration 656: error = 0.7348659, gradient norm = 0.0000715
# [t-SNE] Iteration 657: error = 0.7348039, gradient norm = 0.0000747
# [t-SNE] Iteration 658: error = 0.7347419, gradient norm = 0.0000737
# [t-SNE] Iteration 659: error = 0.7346800, gradient norm = 0.0000671
# [t-SNE] Iteration 660: error = 0.7346183, gradient norm = 0.0000640
# [t-SNE] Iteration 661: error = 0.7345569, gradient norm = 0.0000673
# [t-SNE] Iteration 662: error = 0.7344955, gradient norm = 0.0000664
# [t-SNE] Iteration 663: error = 0.7344342, gradient norm = 0.0000615
# [t-SNE] Iteration 664: error = 0.7343730, gradient norm = 0.0000665
# [t-SNE] Iteration 665: error = 0.7343117, gradient norm = 0.0000627
# [t-SNE] Iteration 666: error = 0.7342506, gradient norm = 0.0000629
# [t-SNE] Iteration 667: error = 0.7341895, gradient norm = 0.0000640
# [t-SNE] Iteration 668: error = 0.7341283, gradient norm = 0.0000635
# [t-SNE] Iteration 669: error = 0.7340672, gradient norm = 0.0000644
# [t-SNE] Iteration 670: error = 0.7340061, gradient norm = 0.0000624
# [t-SNE] Iteration 671: error = 0.7339449, gradient norm = 0.0000607
# [t-SNE] Iteration 672: error = 0.7338839, gradient norm = 0.0000617
# [t-SNE] Iteration 673: error = 0.7338230, gradient norm = 0.0000614
# [t-SNE] Iteration 674: error = 0.7337619, gradient norm = 0.0000620
# [t-SNE] Iteration 675: error = 0.7337009, gradient norm = 0.0000626
# [t-SNE] Iteration 676: error = 0.7336398, gradient norm = 0.0000640
# [t-SNE] Iteration 677: error = 0.7335788, gradient norm = 0.0000644
# [t-SNE] Iteration 678: error = 0.7335179, gradient norm = 0.0000700
# [t-SNE] Iteration 679: error = 0.7334571, gradient norm = 0.0000768
# [t-SNE] Iteration 680: error = 0.7333962, gradient norm = 0.0000758
# [t-SNE] Iteration 681: error = 0.7333353, gradient norm = 0.0000642
# [t-SNE] Iteration 682: error = 0.7332748, gradient norm = 0.0000636
# [t-SNE] Iteration 683: error = 0.7332146, gradient norm = 0.0000737
# [t-SNE] Iteration 684: error = 0.7331545, gradient norm = 0.0000784
# [t-SNE] Iteration 685: error = 0.7330948, gradient norm = 0.0000895
# [t-SNE] Iteration 686: error = 0.7330347, gradient norm = 0.0000845
# [t-SNE] Iteration 687: error = 0.7329745, gradient norm = 0.0000629
# [t-SNE] Iteration 688: error = 0.7329149, gradient norm = 0.0000658
# [t-SNE] Iteration 689: error = 0.7328555, gradient norm = 0.0000708
# [t-SNE] Iteration 690: error = 0.7327959, gradient norm = 0.0000612
# [t-SNE] Iteration 691: error = 0.7327366, gradient norm = 0.0000652
# [t-SNE] Iteration 692: error = 0.7326771, gradient norm = 0.0000632
# [t-SNE] Iteration 693: error = 0.7326176, gradient norm = 0.0000615
# [t-SNE] Iteration 694: error = 0.7325582, gradient norm = 0.0000636
# [t-SNE] Iteration 695: error = 0.7324986, gradient norm = 0.0000614
# [t-SNE] Iteration 696: error = 0.7324390, gradient norm = 0.0000638
# [t-SNE] Iteration 697: error = 0.7323795, gradient norm = 0.0000659
# [t-SNE] Iteration 698: error = 0.7323199, gradient norm = 0.0000664
# [t-SNE] Iteration 699: error = 0.7322603, gradient norm = 0.0000635
# [t-SNE] Iteration 700: error = 0.7322008, gradient norm = 0.0000610
# [t-SNE] Iteration 701: error = 0.7321416, gradient norm = 0.0000659
# [t-SNE] Iteration 702: error = 0.7320824, gradient norm = 0.0000624
# [t-SNE] Iteration 703: error = 0.7320234, gradient norm = 0.0000632
# [t-SNE] Iteration 704: error = 0.7319646, gradient norm = 0.0000640
# [t-SNE] Iteration 705: error = 0.7319060, gradient norm = 0.0000703
# [t-SNE] Iteration 706: error = 0.7318476, gradient norm = 0.0000808
# [t-SNE] Iteration 707: error = 0.7317891, gradient norm = 0.0000839
# ...
# [t-SNE] Iteration 776: error = 0.7279885, gradient norm = 0.0000559
# [t-SNE] Iteration 777: error = 0.7279389, gradient norm = 0.0000541
# [t-SNE] Iteration 778: error = 0.7278896, gradient norm = 0.0000567
# [t-SNE] Iteration 779: error = 0.7278404, gradient norm = 0.0000577
# [t-SNE] Iteration 780: error = 0.7277914, gradient norm = 0.0000561
# [t-SNE] Iteration 781: error = 0.7277427, gradient norm = 0.0000612
# [t-SNE] Iteration 782: error = 0.7276942, gradient norm = 0.0000650
# [t-SNE] Iteration 783: error = 0.7276458, gradient norm = 0.0000638
# [t-SNE] Iteration 784: error = 0.7275980, gradient norm = 0.0000588
# [t-SNE] Iteration 785: error = 0.7275506, gradient norm = 0.0000577
# [t-SNE] Iteration 786: error = 0.7275036, gradient norm = 0.0000602
# [t-SNE] Iteration 787: error = 0.7274570, gradient norm = 0.0000607
# [t-SNE] Iteration 788: error = 0.7274107, gradient norm = 0.0000609
# [t-SNE] Iteration 789: error = 0.7273646, gradient norm = 0.0000581
# [t-SNE] Iteration 790: error = 0.7273189, gradient norm = 0.0000560
# [t-SNE] Iteration 791: error = 0.7272736, gradient norm = 0.0000551
# [t-SNE] Iteration 792: error = 0.7272285, gradient norm = 0.0000542
# [t-SNE] Iteration 793: error = 0.7271836, gradient norm = 0.0000532
# [t-SNE] Iteration 794: error = 0.7271390, gradient norm = 0.0000510
# [t-SNE] Iteration 795: error = 0.7270946, gradient norm = 0.0000519
# [t-SNE] Iteration 796: error = 0.7270503, gradient norm = 0.0000518
# [t-SNE] Iteration 797: error = 0.7270061, gradient norm = 0.0000508
# [t-SNE] Iteration 798: error = 0.7269620, gradient norm = 0.0000523
# [t-SNE] Iteration 799: error = 0.7269180, gradient norm = 0.0000515
# [t-SNE] Iteration 800: error = 0.7268742, gradient norm = 0.0000512
# [t-SNE] Iteration 801: error = 0.7268303, gradient norm = 0.0000500
# [t-SNE] Iteration 802: error = 0.7267866, gradient norm = 0.0000497
# [t-SNE] Iteration 803: error = 0.7267430, gradient norm = 0.0000499
# [t-SNE] Iteration 804: error = 0.7266995, gradient norm = 0.0000499
# [t-SNE] Iteration 805: error = 0.7266561, gradient norm = 0.0000513
# [t-SNE] Iteration 806: error = 0.7266129, gradient norm = 0.0000532
# [t-SNE] Iteration 807: error = 0.7265700, gradient norm = 0.0000630
# [t-SNE] Iteration 808: error = 0.7265272, gradient norm = 0.0000739
# [t-SNE] Iteration 809: error = 0.7264845, gradient norm = 0.0000782
# [t-SNE] Iteration 810: error = 0.7264418, gradient norm = 0.0000648
# [t-SNE] Iteration 811: error = 0.7263994, gradient norm = 0.0000549
# [t-SNE] Iteration 812: error = 0.7263574, gradient norm = 0.0000627
# [t-SNE] Iteration 813: error = 0.7263157, gradient norm = 0.0000627
# [t-SNE] Iteration 814: error = 0.7262743, gradient norm = 0.0000609
# [t-SNE] Iteration 815: error = 0.7262332, gradient norm = 0.0000614
# [t-SNE] Iteration 816: error = 0.7261924, gradient norm = 0.0000549
# [t-SNE] Iteration 817: error = 0.7261520, gradient norm = 0.0000536
# [t-SNE] Iteration 818: error = 0.7261120, gradient norm = 0.0000570
# [t-SNE] Iteration 819: error = 0.7260724, gradient norm = 0.0000552
# [t-SNE] Iteration 820: error = 0.7260330, gradient norm = 0.0000537
# [t-SNE] Iteration 821: error = 0.7259939, gradient norm = 0.0000547
# [t-SNE] Iteration 822: error = 0.7259549, gradient norm = 0.0000490
# [t-SNE] Iteration 823: error = 0.7259164, gradient norm = 0.0000554
# [t-SNE] Iteration 824: error = 0.7258779, gradient norm = 0.0000491
# [t-SNE] Iteration 825: error = 0.7258397, gradient norm = 0.0000514
# [t-SNE] Iteration 826: error = 0.7258016, gradient norm = 0.0000497
# [t-SNE] Iteration 827: error = 0.7257638, gradient norm = 0.0000508
# [t-SNE] Iteration 828: error = 0.7257261, gradient norm = 0.0000500
# [t-SNE] Iteration 829: error = 0.7256885, gradient norm = 0.0000504
# [t-SNE] Iteration 830: error = 0.7256510, gradient norm = 0.0000491
# [t-SNE] Iteration 831: error = 0.7256136, gradient norm = 0.0000496
# [t-SNE] Iteration 832: error = 0.7255763, gradient norm = 0.0000495
# [t-SNE] Iteration 833: error = 0.7255391, gradient norm = 0.0000506
# [t-SNE] Iteration 834: error = 0.7255019, gradient norm = 0.0000494
# [t-SNE] Iteration 835: error = 0.7254647, gradient norm = 0.0000486
# [t-SNE] Iteration 836: error = 0.7254277, gradient norm = 0.0000524
# [t-SNE] Iteration 837: error = 0.7253907, gradient norm = 0.0000530
# [t-SNE] Iteration 838: error = 0.7253536, gradient norm = 0.0000508
# [t-SNE] Iteration 839: error = 0.7253166, gradient norm = 0.0000482
# [t-SNE] Iteration 840: error = 0.7252797, gradient norm = 0.0000481
# [t-SNE] Iteration 841: error = 0.7252430, gradient norm = 0.0000521
# [t-SNE] Iteration 842: error = 0.7252064, gradient norm = 0.0000557
# [t-SNE] Iteration 843: error = 0.7251699, gradient norm = 0.0000611
# [t-SNE] Iteration 844: error = 0.7251334, gradient norm = 0.0000600
# [t-SNE] Iteration 845: error = 0.7250968, gradient norm = 0.0000473
# [t-SNE] Iteration 846: error = 0.7250606, gradient norm = 0.0000503
# [t-SNE] Iteration 847: error = 0.7250245, gradient norm = 0.0000562
# [t-SNE] Iteration 848: error = 0.7249884, gradient norm = 0.0000503
# [t-SNE] Iteration 849: error = 0.7249525, gradient norm = 0.0000486
# [t-SNE] Iteration 850: error = 0.7249168, gradient norm = 0.0000490
# [t-SNE] Iteration 851: error = 0.7248811, gradient norm = 0.0000468
# [t-SNE] Iteration 852: error = 0.7248456, gradient norm = 0.0000503
# [t-SNE] Iteration 853: error = 0.7248101, gradient norm = 0.0000479
# [t-SNE] Iteration 854: error = 0.7247746, gradient norm = 0.0000472
# [t-SNE] Iteration 855: error = 0.7247392, gradient norm = 0.0000472
# [t-SNE] Iteration 856: error = 0.7247039, gradient norm = 0.0000498
# [t-SNE] Iteration 857: error = 0.7246686, gradient norm = 0.0000546
# [t-SNE] Iteration 858: error = 0.7246333, gradient norm = 0.0000547
# [t-SNE] Iteration 859: error = 0.7245979, gradient norm = 0.0000505
# [t-SNE] Iteration 860: error = 0.7245626, gradient norm = 0.0000458
# [t-SNE] Iteration 861: error = 0.7245274, gradient norm = 0.0000503
# [t-SNE] Iteration 862: error = 0.7244922, gradient norm = 0.0000480
# [t-SNE] Iteration 863: error = 0.7244569, gradient norm = 0.0000487
# [t-SNE] Iteration 864: error = 0.7244216, gradient norm = 0.0000508
# [t-SNE] Iteration 865: error = 0.7243863, gradient norm = 0.0000487
# [t-SNE] Iteration 866: error = 0.7243508, gradient norm = 0.0000498
# [t-SNE] Iteration 867: error = 0.7243152, gradient norm = 0.0000476
# [t-SNE] Iteration 868: error = 0.7242797, gradient norm = 0.0000511
# [t-SNE] Iteration 869: error = 0.7242439, gradient norm = 0.0000483
# [t-SNE] Iteration 870: error = 0.7242081, gradient norm = 0.0000458
# [t-SNE] Iteration 871: error = 0.7241722, gradient norm = 0.0000479
# [t-SNE] Iteration 872: error = 0.7241363, gradient norm = 0.0000514
# [t-SNE] Iteration 873: error = 0.7241002, gradient norm = 0.0000545
# [t-SNE] Iteration 874: error = 0.7240640, gradient norm = 0.0000530
# [t-SNE] Iteration 875: error = 0.7240276, gradient norm = 0.0000505
# [t-SNE] Iteration 876: error = 0.7239912, gradient norm = 0.0000497
# [t-SNE] Iteration 877: error = 0.7239547, gradient norm = 0.0000498
# [t-SNE] Iteration 878: error = 0.7239180, gradient norm = 0.0000485
# [t-SNE] Iteration 879: error = 0.7238814, gradient norm = 0.0000512
# [t-SNE] Iteration 880: error = 0.7238445, gradient norm = 0.0000499
# [t-SNE] Iteration 881: error = 0.7238076, gradient norm = 0.0000484
# [t-SNE] Iteration 882: error = 0.7237706, gradient norm = 0.0000485
# [t-SNE] Iteration 883: error = 0.7237337, gradient norm = 0.0000490
# [t-SNE] Iteration 884: error = 0.7236966, gradient norm = 0.0000474
# [t-SNE] Iteration 885: error = 0.7236596, gradient norm = 0.0000473
# [t-SNE] Iteration 886: error = 0.7236226, gradient norm = 0.0000467
# [t-SNE] Iteration 887: error = 0.7235856, gradient norm = 0.0000466
# [t-SNE] Iteration 888: error = 0.7235485, gradient norm = 0.0000477
# [t-SNE] Iteration 889: error = 0.7235114, gradient norm = 0.0000480
# [t-SNE] Iteration 890: error = 0.7234743, gradient norm = 0.0000497
# [t-SNE] Iteration 891: error = 0.7234371, gradient norm = 0.0000499
# [t-SNE] Iteration 892: error = 0.7233998, gradient norm = 0.0000475
# [t-SNE] Iteration 893: error = 0.7233626, gradient norm = 0.0000481
# [t-SNE] Iteration 894: error = 0.7233255, gradient norm = 0.0000509
# [t-SNE] Iteration 895: error = 0.7232884, gradient norm = 0.0000517
# [t-SNE] Iteration 896: error = 0.7232512, gradient norm = 0.0000505
# [t-SNE] Iteration 897: error = 0.7232142, gradient norm = 0.0000469
# [t-SNE] Iteration 898: error = 0.7231773, gradient norm = 0.0000469
# [t-SNE] Iteration 899: error = 0.7231405, gradient norm = 0.0000491
# [t-SNE] Iteration 900: error = 0.7231039, gradient norm = 0.0000513
# [t-SNE] Iteration 901: error = 0.7230674, gradient norm = 0.0000535
# [t-SNE] Iteration 902: error = 0.7230310, gradient norm = 0.0000514
# [t-SNE] Iteration 903: error = 0.7229947, gradient norm = 0.0000468
# [t-SNE] Iteration 904: error = 0.7229586, gradient norm = 0.0000494
# [t-SNE] Iteration 905: error = 0.7229227, gradient norm = 0.0000507
# [t-SNE] Iteration 906: error = 0.7228868, gradient norm = 0.0000450
# [t-SNE] Iteration 907: error = 0.7228512, gradient norm = 0.0000481
# [t-SNE] Iteration 908: error = 0.7228158, gradient norm = 0.0000504
# [t-SNE] Iteration 909: error = 0.7227804, gradient norm = 0.0000500
# [t-SNE] Iteration 910: error = 0.7227452, gradient norm = 0.0000491
# [t-SNE] Iteration 911: error = 0.7227102, gradient norm = 0.0000454
# [t-SNE] Iteration 912: error = 0.7226754, gradient norm = 0.0000468
# [t-SNE] Iteration 913: error = 0.7226409, gradient norm = 0.0000468
# [t-SNE] Iteration 914: error = 0.7226064, gradient norm = 0.0000456
# [t-SNE] Iteration 915: error = 0.7225723, gradient norm = 0.0000482
# [t-SNE] Iteration 916: error = 0.7225383, gradient norm = 0.0000557
# [t-SNE] Iteration 917: error = 0.7225047, gradient norm = 0.0000658
# [t-SNE] Iteration 918: error = 0.7224711, gradient norm = 0.0000702
# [t-SNE] Iteration 919: error = 0.7224375, gradient norm = 0.0000568
# [t-SNE] Iteration 920: error = 0.7224039, gradient norm = 0.0000506
# [t-SNE] Iteration 921: error = 0.7223706, gradient norm = 0.0000568
# [t-SNE] Iteration 922: error = 0.7223376, gradient norm = 0.0000487
# [t-SNE] Iteration 923: error = 0.7223050, gradient norm = 0.0000577
# [t-SNE] Iteration 924: error = 0.7222726, gradient norm = 0.0000703
# [t-SNE] Iteration 925: error = 0.7222407, gradient norm = 0.0000842
# [t-SNE] Iteration 926: error = 0.7222084, gradient norm = 0.0000758
# [t-SNE] Iteration 927: error = 0.7221762, gradient norm = 0.0000484
# [t-SNE] Iteration 928: error = 0.7221446, gradient norm = 0.0000544
# [t-SNE] Iteration 929: error = 0.7221133, gradient norm = 0.0000623
# [t-SNE] Iteration 930: error = 0.7220817, gradient norm = 0.0000428
# [t-SNE] Iteration 931: error = 0.7220508, gradient norm = 0.0000566
# [t-SNE] Iteration 932: error = 0.7220196, gradient norm = 0.0000477
# [t-SNE] Iteration 933: error = 0.7219888, gradient norm = 0.0000525
# [t-SNE] Iteration 934: error = 0.7219579, gradient norm = 0.0000478
# [t-SNE] Iteration 935: error = 0.7219272, gradient norm = 0.0000470
# [t-SNE] Iteration 936: error = 0.7218966, gradient norm = 0.0000484
# [t-SNE] Iteration 937: error = 0.7218661, gradient norm = 0.0000497
# [t-SNE] Iteration 938: error = 0.7218356, gradient norm = 0.0000454
# [t-SNE] Iteration 939: error = 0.7218053, gradient norm = 0.0000487
# [t-SNE] Iteration 940: error = 0.7217750, gradient norm = 0.0000488
# [t-SNE] Iteration 941: error = 0.7217449, gradient norm = 0.0000500
# [t-SNE] Iteration 942: error = 0.7217148, gradient norm = 0.0000462
# [t-SNE] Iteration 943: error = 0.7216849, gradient norm = 0.0000482
# [t-SNE] Iteration 944: error = 0.7216550, gradient norm = 0.0000470
# [t-SNE] Iteration 945: error = 0.7216252, gradient norm = 0.0000460
# [t-SNE] Iteration 946: error = 0.7215956, gradient norm = 0.0000454
# [t-SNE] Iteration 947: error = 0.7215660, gradient norm = 0.0000450
# [t-SNE] Iteration 948: error = 0.7215366, gradient norm = 0.0000430
# [t-SNE] Iteration 949: error = 0.7215075, gradient norm = 0.0000453
# [t-SNE] Iteration 950: error = 0.7214783, gradient norm = 0.0000425
# [t-SNE] Iteration 951: error = 0.7214493, gradient norm = 0.0000439
# [t-SNE] Iteration 952: error = 0.7214203, gradient norm = 0.0000430
# [t-SNE] Iteration 953: error = 0.7213914, gradient norm = 0.0000470
# [t-SNE] Iteration 954: error = 0.7213624, gradient norm = 0.0000467
# [t-SNE] Iteration 955: error = 0.7213334, gradient norm = 0.0000430
# [t-SNE] Iteration 956: error = 0.7213044, gradient norm = 0.0000418
# [t-SNE] Iteration 957: error = 0.7212755, gradient norm = 0.0000452
# [t-SNE] Iteration 958: error = 0.7212466, gradient norm = 0.0000504
# [t-SNE] Iteration 959: error = 0.7212177, gradient norm = 0.0000535
# [t-SNE] Iteration 960: error = 0.7211887, gradient norm = 0.0000560
# [t-SNE] Iteration 961: error = 0.7211596, gradient norm = 0.0000471
# [t-SNE] Iteration 962: error = 0.7211306, gradient norm = 0.0000435
# [t-SNE] Iteration 963: error = 0.7211016, gradient norm = 0.0000481
# [t-SNE] Iteration 964: error = 0.7210726, gradient norm = 0.0000460
# [t-SNE] Iteration 965: error = 0.7210437, gradient norm = 0.0000438
# [t-SNE] Iteration 966: error = 0.7210148, gradient norm = 0.0000448
# [t-SNE] Iteration 967: error = 0.7209860, gradient norm = 0.0000439
# [t-SNE] Iteration 968: error = 0.7209572, gradient norm = 0.0000437
# [t-SNE] Iteration 969: error = 0.7209285, gradient norm = 0.0000483
# [t-SNE] Iteration 970: error = 0.7209001, gradient norm = 0.0000655
# [t-SNE] Iteration 971: error = 0.7208724, gradient norm = 0.0001040
# [t-SNE] Iteration 972: error = 0.7208452, gradient norm = 0.0001464
# [t-SNE] Iteration 973: error = 0.7208149, gradient norm = 0.0000897
# [t-SNE] Iteration 974: error = 0.7207861, gradient norm = 0.0000783
# [t-SNE] Iteration 975: error = 0.7207582, gradient norm = 0.0001045
# [t-SNE] Iteration 976: error = 0.7207287, gradient norm = 0.0000562
# [t-SNE] Iteration 977: error = 0.7207009, gradient norm = 0.0000897
# [t-SNE] Iteration 978: error = 0.7206717, gradient norm = 0.0000516
# [t-SNE] Iteration 979: error = 0.7206437, gradient norm = 0.0000755
# [t-SNE] Iteration 980: error = 0.7206152, gradient norm = 0.0000610
# [t-SNE] Iteration 981: error = 0.7205867, gradient norm = 0.0000545
# [t-SNE] Iteration 982: error = 0.7205586, gradient norm = 0.0000645
# [t-SNE] Iteration 983: error = 0.7205300, gradient norm = 0.0000428
# [t-SNE] Iteration 984: error = 0.7205021, gradient norm = 0.0000660
# [t-SNE] Iteration 985: error = 0.7204737, gradient norm = 0.0000532
# [t-SNE] Iteration 986: error = 0.7204455, gradient norm = 0.0000559
# [t-SNE] Iteration 987: error = 0.7204173, gradient norm = 0.0000490
# [t-SNE] Iteration 988: error = 0.7203891, gradient norm = 0.0000445
# [t-SNE] Iteration 989: error = 0.7203612, gradient norm = 0.0000545
# [t-SNE] Iteration 990: error = 0.7203330, gradient norm = 0.0000420
# [t-SNE] Iteration 991: error = 0.7203051, gradient norm = 0.0000468
# [t-SNE] Iteration 992: error = 0.7202771, gradient norm = 0.0000460
# [t-SNE] Iteration 993: error = 0.7202491, gradient norm = 0.0000443
# [t-SNE] Iteration 994: error = 0.7202213, gradient norm = 0.0000517
# [t-SNE] Iteration 995: error = 0.7201934, gradient norm = 0.0000449
# [t-SNE] Iteration 996: error = 0.7201656, gradient norm = 0.0000452
# [t-SNE] Iteration 997: error = 0.7201378, gradient norm = 0.0000436
# [t-SNE] Iteration 998: error = 0.7201101, gradient norm = 0.0000436
# [t-SNE] Iteration 999: error = 0.7200825, gradient norm = 0.0000432
# [t-SNE] Iteration 1000: error = 0.7200550, gradient norm = 0.0000418
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
